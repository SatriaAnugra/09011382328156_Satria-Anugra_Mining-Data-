# %% [markdown]
# **SATRIA ANUGRA**
#
# **(09011382328156)**

# %% [markdown]
# 1. Import Dataset:
# * Baca dataset yang diberikan menggunakan Pandas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from google.colab import files
import io

# %%
filenya = files.upload()
# Out:
#      <input type="file" id="files-77c90507-378c-44ed-9bcb-48ca2f986782" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-77c90507-378c-44ed-9bcb-48ca2f986782">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filenya
# Out:
# {'heart_disease_uci (3).csv': b'id,age,sex,dataset,cp,trestbps,chol,fbs,restecg,thalch,exang,oldpeak,slope,ca,thal,num\n1,63,Male,Cleveland,typical angina,145,233,TRUE,lv hypertrophy,150,FALSE,2.3,downsloping,0,fixed defect,0\n2,67,Male,Cleveland,asymptomatic,160,286,FALSE,lv hypertrophy,108,TRUE,1.5,flat,3,normal,2\n3,67,Male,Cleveland,asymptomatic,120,229,FALSE,lv hypertrophy,129,TRUE,2.6,flat,2,reversable defect,1\n4,37,Male,Cleveland,non-anginal,130,250,FALSE,normal,187,FALSE,3.5,downsloping,0,normal,0\n5,41,Female,Cleveland,atypical angina,130,204,FALSE,lv hypertrophy,172,FALSE,1.4,upsloping,0,normal,0\n6,56,Male,Cleveland,atypical angina,120,236,FALSE,normal,178,FALSE,0.8,upsloping,0,normal,0\n7,62,Female,Cleveland,asymptomatic,140,268,FALSE,lv hypertrophy,160,FALSE,3.6,downsloping,2,normal,3\n8,57,Female,Cleveland,asymptomatic,120,354,FALSE,normal,163,TRUE,0.6,upsloping,0,normal,0\n9,63,Male,Cleveland,asymptomatic,130,254,FALSE,lv hypertrophy,147,FALSE,1.4,flat,1,reversable de
# ...

# %%
df = pd.read_csv(io.StringIO(filenya['heart_disease_uci (3).csv'].decode('utf-8'))) # Use the correct key 'heart_disease_uci (2).csv'
display(df)
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %% [markdown]
# 2.	Eksplorasi Awal:
# * Tampilkan 5 baris pertama dan terakhir dari dataset.
# * Lihat informasi tentang dataset (tipe data, jumlah entri, jumlah kolom).
# * Cek nilai missing dan outliers.

# %%
print("5 Baris Pertama:")
display(df.head(),)
# Out:
# 5 Baris Pertama:
#    id  age  sex  dataset  cp  trestbps   chol  fbs  restecg  thalch  exang  \
# 0   1   63  NaN      NaN NaN     145.0  233.0  1.0      NaN   150.0    0.0
# 1   2   67  NaN      NaN NaN     160.0  286.0  0.0      NaN   108.0    1.0
# 2   3   67  NaN      NaN NaN     120.0  229.0  0.0      NaN   129.0    1.0
# 3   4   37  NaN      NaN NaN     130.0  250.0  0.0      NaN   187.0    0.0
# 4   5   41  NaN      NaN NaN     130.0  204.0  0.0      NaN   172.0    0.0
#
#    oldpeak  slope   ca  thal  num
# 0      2.3    NaN  0.0   NaN    0
# 1      1.5    NaN  3.0   NaN    2
# 2      2.6    NaN  2.0   NaN    1
# 3      3.5    NaN  0.0   NaN    0
# 4      1.4    NaN  0.0   NaN    0

# %%
print("5 Baris Terakhir:")
display(df.tail(),)
# Out:
# 5 Baris Terakhir:
#       id  age  sex  dataset  cp  trestbps   chol  fbs  restecg  thalch  exang  \
# 915  916   54  NaN      NaN NaN     127.0  333.0  1.0      NaN   154.0    0.0
# 916  917   62  NaN      NaN NaN       NaN  139.0  0.0      NaN     NaN    NaN
# 917  918   55  NaN      NaN NaN     122.0  223.0  1.0      NaN   100.0    0.0
# 918  919   58  NaN      NaN NaN       NaN  385.0  1.0      NaN     NaN    NaN
# 919  920   62  NaN      NaN NaN     120.0  254.0  0.0      NaN    93.0    1.0
#
#      oldpeak  slope  ca  thal  num
# 915      0.0    NaN NaN   NaN    1
# 916      NaN    NaN NaN   NaN    0
# 917      0.0    NaN NaN   NaN    2
# 918      NaN    NaN NaN   NaN    0
# 919      0.0    NaN NaN   NaN    1

# %%
print("Informasi Dataset:")
df.info()
print("\n")
# Out:
# Informasi Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
print("Nilai yang hilang per kolom:")
missing_values = df.isnull().sum()
print(missing_values)
print("\n")
# Out:
# Nilai yang hilang per kolom:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64

# %%
df = df.apply(pd.to_numeric, errors='coerce')
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# %%
outliers = df[((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR)))]

# %%
print("Jumlah outliers per kolom:")
print(outliers.count())
# Out:
# Jumlah outliers per kolom:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     28
# chol        183
# fbs         138
# restecg       0
# thalch        2
# exang         0
# oldpeak      16
# slope         0
# ca           20
# thal          0
# num           0
# dtype: int64

# %% [markdown]
# 3.	Statistik Deskriptif:
# * Hitung dan tampilkan mean, median, mode, standar deviasi, variansi, skewness, dan kurtosis untuk kolom numerik.
# * Hitung korelasi antar variabel numerik.

# %%
stats = {
    "Mean": df.mean(),
    "Median": df.median(),
    "Mode": df.mode().iloc[0],
    "Standar Deviasi": df.std(),
    "Variansi": df.var(),
    "Skewness": df.skew(),
    "Kurtosis": df.kurtosis()
}

# %%
display(stats)
# Out:
# {'Mean': id          460.500000
#  age          53.510870
#  sex                NaN
#  dataset            NaN
#  cp                 NaN
#  trestbps    132.132404
#  chol        199.130337
#  fbs           0.166265
#  restecg            NaN
#  thalch      137.545665
#  exang         0.389595
#  oldpeak       0.878788
#  slope              NaN
#  ca            0.676375
#  thal               NaN
#  num           0.995652
#  dtype: float64,
#  'Median': id          460.5
#  age          54.0
#  sex           NaN
#  dataset       NaN
#  cp            NaN
#  trestbps    130.0
#  chol        223.0
#  fbs           0.0
#  restecg       NaN
#  thalch      140.0
#  exang         0.0
#  oldpeak       0.5
#  slope         NaN
#  ca            0.0
#  thal          NaN
#  num           1.0
#  dtype: float64,
#  'Mode': id            1.0
#  age          54.0
#  sex           NaN
#  dataset       NaN
#  cp            NaN
#  trestbps    120.0
#  chol          0.0
#  fbs           0.0
# ...

# %%
filtered_columns = ['age', 'trestbps', 'chol', 'thalch', 'oldpeak', 'ca', 'num']
filtered_corr_matrix = df[filtered_columns].corr()

plt.figure(figsize=(18, 9))
sns.heatmap(filtered_corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True, square=True)
plt.title('Korelasi Antar Variabel Numerik')
plt.show()

# %% [markdown]
# 4.	Visualisasi Data:
# *	Buat histogram dan box plot untuk setiap variabel numerik.
# *	Buat scatter plot untuk pasangan variabel yang memiliki korelasi tinggi.

# %%
print("Histogram untuk setiap variabel numerik:")
df.hist(bins=15, figsize=(15, 10))
plt.show()
# Out:
# Histogram untuk setiap variabel numerik:

# %%
print("Boxplot untuk setiap variabel numerik:")
df.boxplot(figsize=(15, 10))
plt.xticks(rotation=45)
plt.show()
# Out:
# Boxplot untuk setiap variabel numerik:

# %%
numeric_columns = df.select_dtypes(include='number')

# %%
correlation_matrix = numeric_columns.corr()

# %%
threshold = 0.70

# %%
for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > threshold:
            colname1 = correlation_matrix.columns[i]
            colname2 = correlation_matrix.columns[j]
            print(f"Korelasi tinggi terdeteksi antara {colname1} dan {colname2}: {correlation_matrix.iloc[i, j]}")

# %% [markdown]
# 5.	Laporan:
# * Buat laporan singkat yang menjelaskan hasil eksplorasi dan analisis data, termasuk penemuan yang signifikan seperti distribusi yang tidak normal, korelasi kuat antar variabel, dan adanya outliers atau missing values.

# %% [markdown]
# *Laporan Singkat Analisis Data*
#
# ** Berikut Adalah ringkasan dari hasil dari analisis dataset kaggle yang digunakan yaitu ; heart_disease_uci.cvs , hasil dari percobaan ini adalah untuk mengidentifikasi distribusi data, korelasi antar variabel, serta mendeteksi outliers dan missing values.
#
# *1. Import Data:*
# - **proses mengambil data dari database lain kali ini percobaan diambil dari kaggle ; heart_disease_uci.cvs berikut https://www.kaggle.com/datasets/redwankarimsony/heart-disease-data
#
# *2. Eksplorasi Awal:*
# - **Menampilkan 5 Baris Pertama dan Terakhir:**
# - Tampilan 5 baris pertama dan terakhir memberikan gambaran awal tentang struktur data dan nilai-nilai yang terkandung di dalamnya.membantu untuk mengidentifikasi format atau jenis data yang mungkin memerlukan pemrosesan tambahan.
# - **Nilai yang Hilang**: Jika ada nilai yang hilang, memutuskan bagaimana menanganinya agar analisis tetap valid.
# - **Outliers**: Penting untuk mengevaluasi apakah outliers memerlukan penghapusan atau interpretasi tambahan, tergantung pada tujuan analisis.
#
# *3. Deteksi Outliers:*
# - Outliers diidentifikasi dalam variabel [sebutkan variabel], di mana beberapa data titik berada jauh dari distribusi utama. Ini bisa disebabkan oleh kesalahan input data atau fenomena yang memang terjadi dalam data.
# - Untuk mengatasi outliers, dapat dipertimbangkan untuk melakukan transformasi data atau menggunakan metode robust dalam analisis lanjutan.
#
# *4. Missing Values:*
# - Ditemukan adanya missing values pada variabel [sebutkan variabel], dengan persentase sebesar [nilai%] dari total data.
# - Missing values ini dapat diatasi dengan beberapa pendekatan seperti imputasi median, mean, atau menggunakan model prediktif untuk mengisi nilai yang hilang.
#
# *5. Kesimpulan:*
# Analisis ini mengungkap beberapa aspek penting dari dataset, seperti adanya distribusi yang tidak normal pada beberapa variabel, korelasi yang kuat antara beberapa pasangan variabel, serta adanya outliers dan missing values. Langkah-langkah lanjutan diperlukan untuk menangani outliers dan missing values sebelum melakukan analisis lebih mendalam atau model prediktif.
